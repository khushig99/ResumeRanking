# %%
# !pip install python-pdfbox
# !pip install pyLDAvis
# !pip install skillNer

# from google.colab import drive
# drive.mount('/content/drive')


import csv
import os
import glob
import re
import nltk
import spacy
from spacy.pipeline import EntityRuler
from spacy.lang.en import English
from spacy.tokens import Doc
import gensim 

from gensim import corpora
import plotly.express as px
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud

from pdfbox import PDFBox
import hashlib # file ids
import spacy.cli
spacy.cli.download("en_core_web_lg")
#warning
import warnings 
warnings.filterwarnings('ignore')

nltk.download(['stopwords','wordnet'])

nltk.download('omw-1.4')
nlp=spacy.load('en_core_web_lg')


def extract_pdf_text(folder_path):
    text_list = []

    for file in glob.glob(os.path.join(folder_path, "*.pdf")):
        file_name = os.path.basename(file)
        pdf = PDFBox()
        text = pdf.extract_text(file)
        if text:
            text_list.append({"file_name": file_name, "text": text})
        else:
            with open(f"{file_name}.txt", "w") as f:
                f.write("")

    

def text_to_csv(folder_path):
    csv_file = open('text_files.csv', 'w', newline='')
    writer = csv.writer(csv_file)
    writer.writerow(['ID', 'filename', 'text'])

    def generate_id(filename):
        return int(hashlib.md5(filename.encode('utf-8')).hexdigest(), 16)% 100000 #to limit the unique ID to less or equal to 5 digits
    
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r') as file:
                text = file.read()
                id = generate_id(filename)
                writer.writerow([id, filename, text])

    csv_file.close()

def load_csv(file_path):
    df = pd.read_csv(file_path)
    return df

from spacy.matcher import PhraseMatcher

# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)

def extract_skills(text):
    
    annotations = skill_extractor.annotate(text)
    doc_node_values = set([x['doc_node_value'] for x in annotations['results']['full_matches']])
    return ', '.join(doc_node_values)

def create_wordcloud(df, column_name):
    skill_cloud = ""
    for i in df[column_name].values:
        skill_cloud += i + " "

    plt.figure(figsize=(8, 8))

    x, y = np.ogrid[:300, :300]

    mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
    mask = 255 * mask.astype(int)

    wc = WordCloud(
        width=800,
        height=800,
        background_color="white",
        min_font_size=6,
        repeat=True,
        mask=mask,
    )
    wc.generate(skill_cloud)

    plt.axis("off")
    plt.imshow(wc, interpolation="bilinear")
    plt.title("Most Used Skill Words in Resume", fontsize=20)


def plot_skills_histogram(df):
    df_skills = df.copy()
    df_skills['skills'] = df_skills['skills'].str.split(',')
    df_skills = df_skills.set_index(['ID'])['skills'].apply(pd.Series).stack()
    df_skills = df_skills.reset_index()
    df_skills = df_skills.rename(columns={0: "skill"})
    df_skills['skill'].value_counts().plot(kind='bar')
    plt.xlabel("Skills")
    plt.ylabel("Number of Candidates")
    plt.title("Skills Histogram")
    plt.show()


folder_path = "/content/drive/MyDrive/Uploaded Resumes/Business Analytics"


# To extract text from pdf files
extract_pdf_text(folder_path)


# To create a csv file from the extracted text
text_to_csv(folder_path)

# To load the csv file
file_path = 'text_files.csv'
df = load_csv(file_path)



# To preprocess the text in the csv file
clean = []
for i in range(df.shape[0]):
    review = re.sub(
        '(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?"',
        " ",
        df["text"].iloc[i],
    )
    review = review.lower()
    review = review.split()
    lm = WordNetLemmatizer()
    review = [
        lm.lemmatize(word)
        for word in review
        if not word in set(stopwords.words("english"))
    ]
    review = " ".join(review)
    clean.append(review)

df["Clean_Resume"] = clean

df['skills'] = df['Clean_Resume'].apply(extract_skills)
df.head()

create_wordcloud(df, "skills")
def rank_resumes(df, keywords, scores):
    scores_dict = dict(zip(keywords, scores))
    df["rank"] = 0
    for i in range(df.shape[0]):
        for keyword in keywords:
            if keyword in df["skills"].iloc[i]:
                df["rank"].iloc[i] += scores_dict[keyword]
    df = df.sort_values("rank", ascending=False)
    return df
keywords = ['business development','machine learn', 'time management']# key words to be searched in skills
scores = [2, 3]# scores for the above skills in respective order
df = rank_resumes(df, keywords, scores)
df.to_csv('/content/drive/MyDrive/Uploaded Resumes/ranked_resumesBA.csv', index=False)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-pdfbox in c:\users\khush\appdata\roaming\python\python311\site-packages (0.1.8.1)
# Requirement already satisfied: appdirs in c:\users\khush\appdata\roaming\python\python311\site-packages (from python-pdfbox) (1.4.4)
# Requirement already satisfied: jpype1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from python-pdfbox) (1.5.0)
# Requirement already satisfied: setuptools in c:\users\khush\appdata\roaming\python\python311\site-packages (from python-pdfbox) (75.5.0)
# Requirement already satisfied: packaging in c:\users\khush\appdata\roaming\python\python311\site-packages (from jpype1->python-pdfbox) (22.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyLDAvis in c:\users\khush\appdata\roaming\python\python311\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: numexpr in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (2.8.7)
# Requirement already satisfied: funcy in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (1.5.0)
# Requirement already satisfied: gensim in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in c:\users\khush\appdata\roaming\python\python311\site-packages (from pyLDAvis) (75.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->pyLDAvis) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas>=2.0.0->pyLDAvis) (2023.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from gensim->pyLDAvis) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from jinja2->pyLDAvis) (2.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\khush\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: wrapt in c:\users\khush\appdata\roaming\python\python311\site-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.16.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# langchain 0.0.304 requires numpy<2,>=1, but you have numpy 2.0.2 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: skillNer in c:\users\khush\appdata\roaming\python\python311\site-packages (1.0.3)
# Requirement already satisfied: numpy in c:\users\khush\appdata\roaming\python\python311\site-packages (from skillNer) (1.26.4)
# Requirement already satisfied: pandas in c:\users\khush\appdata\roaming\python\python311\site-packages (from skillNer) (2.2.2)
# Requirement already satisfied: nltk in c:\users\khush\appdata\roaming\python\python311\site-packages (from skillNer) (3.8.1)
# Requirement already satisfied: spacy in c:\users\khush\appdata\roaming\python\python311\site-packages (from skillNer) (3.8.2)
# Requirement already satisfied: jellyfish in c:\users\khush\appdata\roaming\python\python311\site-packages (from skillNer) (1.1.0)
# Requirement already satisfied: click in c:\users\khush\appdata\roaming\python\python311\site-packages (from nltk->skillNer) (8.1.3)
# Requirement already satisfied: joblib in c:\users\khush\appdata\roaming\python\python311\site-packages (from nltk->skillNer) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\khush\appdata\roaming\python\python311\site-packages (from nltk->skillNer) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\khush\appdata\roaming\python\python311\site-packages (from nltk->skillNer) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas->skillNer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas->skillNer) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pandas->skillNer) (2023.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (0.13.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (75.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (22.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from spacy->skillNer) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy->skillNer) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->skillNer) (0.5.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->skillNer) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->skillNer) (4.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\khush\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->skillNer) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khush\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\khush\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khush\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy->skillNer) (2023.5.7)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from thinc<8.4.0,>=8.3.0->spacy->skillNer) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from thinc<8.4.0,>=8.3.0->spacy->skillNer) (0.1.5)
# Collecting numpy (from skillNer)
#   Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: colorama in c:\users\khush\appdata\roaming\python\python311\site-packages (from tqdm->nltk->skillNer) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from typer<1.0.0,>=0.3.0->spacy->skillNer) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from typer<1.0.0,>=0.3.0->spacy->skillNer) (13.6.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from weasel<0.5.0,>=0.1.0->spacy->skillNer) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from weasel<0.5.0,>=0.1.0->spacy->skillNer) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from jinja2->spacy->skillNer) (2.1.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\khush\appdata\roaming\python\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->skillNer) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->skillNer) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\khush\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->skillNer) (2.13.0)
# Requirement already satisfied: wrapt in c:\users\khush\appdata\roaming\python\python311\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->skillNer) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\khush\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->skillNer) (0.1.2)
# Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.0.2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 18
#      16 from spacy.lang.en import English
#      17 from spacy.tokens import Doc
# ---> 18 import gensim
#      20 from gensim import corpora
#      21 import plotly.express as px
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
